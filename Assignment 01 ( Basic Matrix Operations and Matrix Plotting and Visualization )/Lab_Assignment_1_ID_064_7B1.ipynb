# %%
"""

University of Information Technology and Sciences (UITS)
          Name      : Md. Rifat Hassan
          ID        : 0432310005101064
          Semester  : Spring-2026
          Batch     : 53
          Section   : 7B1
          Department: CSE


          Course Code : CSE 413
          Course Title: Simulation and Modeling Lab

"""

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"""

Assignment 1: Basic Matrix Operations
1. Create two 3×3 matrices with random integers in Python.
2. Perform addition, subtraction, and multiplication operations on these matrices.
3. Compute the determinant, inverse, and rank of one of the matrices.

"""


# Random Matrix
a = np.random.randint(0,10,size=(3,3))
b = np.random.randint(0,10,size=(3,3))

# Sum of 2 Random Matrix
sum = a + b

# Subtraction of 2 Random Matrix
sub = a - b

# Multiplication of 2 Random Matrix
mul = np.dot(a,b)

# Matrix Diterminent
det_a= np.linalg.det(a)
det_b = np.linalg.det(b)

# Matrix Inverse for a
if(np.linalg.det(a)!=0):
  inv_a = np.linalg.inv(a)
else:
  print("Matrix is Singular")

# Matrix Inverse for b
if(np.linalg.det(b)!=0):
  inv_b = np.linalg.inv(b)
else:
  print("Matrix is Singular")

# Rank of the Matrix
rank_a = np.linalg.matrix_rank(a)
rank_b = np.linalg.matrix_rank(b)

# Print Functions
print("Matrix A: \n",a,"\n")
print("Matrix B: \n",b,"\n")
print("Sum of Matrix: \n",sum,"\n")
print("Subtraction of Matrix: \n",sub,"\n")
print("Multiplication of Matrix: \n",mul,"\n")
print("Matrix Determinant of Mat A: \n",det_a,"\n")
print("Matrix Determinant of Mat B: \n",det_b,"\n")
print("Matrix Inverse of Mat A: \n",inv_a,"\n")
print("Matrix Inverse of Mat B: \n",inv_b,"\n")
print("Matrix Rank of Mat A: \n",rank_a,"\n")
print("Matrix Rank of Mat B: \n",rank_b,"\n")
# Out:
# Matrix A:
#  [[3 2 0]
#  [1 5 1]
#  [9 5 7]]
#
# Matrix B:
#  [[2 9 0]
#  [3 1 6]
#  [5 6 2]]
#
# Sum of Matrix:
#  [[ 5 11  0]
#  [ 4  6  7]
#  [14 11  9]]
#
# Subtraction of Matrix:
#  [[ 1 -7  0]
#  [-2  4 -5]
#  [ 4 -1  5]]
#
# Multiplication of Matrix:
#  [[ 12  29  12]
#  [ 22  20  32]
#  [ 68 128  44]]
#
# Matrix Determinant of Mat A:
#  94.0
#
# Matrix Determinant of Mat B:
#  147.99999999999994
#
# Matrix Inverse of Mat A:
#  [[ 0.31914894 -0.14893617  0.0212766 ]
#  [ 0.0212766   0.22340426 -0.03191489]
#  [-0.42553191  0.03191489  0.13829787]]
#
# Matrix Inverse of Mat B:
#  [[-0.22972973 -0.12162162  0.36486486]
#  [ 0.16216216  0.02702703 -0.08108108]
#  [ 0.08783784  0.22297297 -0.16891892]]
#
# Matrix Rank of Mat A:
#  3
#
# Matrix Rank of Mat B:
#  3

# %%
"""

Assignment 2: Matrix Plotting and Visualization
1. Generate and Plot Two Random Vectors:
a. Create two vectors, each containing 15 random floats of your choice.
b. Plot these vectors on the same graph using matplotlib to compare how they look.
c. Label the axes appropriately and give the plot a title.

"""

# Random Matrix with float
A = np.random.uniform(11,30, size=(5,3))
B = np.random.uniform(31,40, size=(5,3))

print("Matrix A: \n",A,"\n")
print("Matrix B: \n",B,"\n")

# Flattem 1D Array
flat_A = A.flatten()
flat_B = B.flatten()

print("Flattened Matrix A: \n",flat_A,"\n")
print("Flattened Matrix B: \n",flat_B,"\n")

# Create an Index for x-Axis
x = np.arange(len(flat_A))

# Line Plot
plt.plot(x, flat_A, marker = "o", linestyle = "-", label="Matrix A")
plt.plot(x, flat_B, marker = "s", linestyle = "--", label="Matrix B")

# Label and Title
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Line Graph of Float Flatten Matrices A and B")
plt.legend()
plt.grid(True)

# Show the Plot
plt.show()
# Out:
# Matrix A:
#  [[22.62214097 24.15481658 21.28794037]
#  [14.61429382 29.87199918 23.45478566]
#  [17.12004962 12.87683625 26.84107916]
#  [15.36710611 21.71373445 13.46474386]
#  [20.8428454  19.03471997 11.82999595]]
#
# Matrix B:
#  [[39.12809643 34.23873705 37.42970509]
#  [36.45867491 38.21955174 37.63083859]
#  [38.95020426 31.90871493 33.25813214]
#  [31.54797729 31.90443116 39.49190608]
#  [35.96477237 36.99927155 31.78300458]]
#
# Flattened Matrix A:
#  [22.62214097 24.15481658 21.28794037 14.61429382 29.87199918 23.45478566
#  17.12004962 12.87683625 26.84107916 15.36710611 21.71373445 13.46474386
#  20.8428454  19.03471997 11.82999595]
#
# Flattened Matrix B:
#  [39.12809643 34.23873705 37.42970509 36.45867491 38.21955174 37.63083859
#  38.95020426 31.90871493 33.25813214 31.54797729 31.90443116 39.49190608
#  35.96477237 36.99927155 31.78300458]
